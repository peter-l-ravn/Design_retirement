# %%
# %load_ext autoreload
# %autoreload 2
import time
import numpy as np
import pandas as pd
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from estimation_fct_v2 import *
from graph_format import *

# Load model
from model_inflexible import ModelClass

model = ModelClass() 

par = model.par
sol = model.sol
sim = model.sim

# %%
_, _, moments = prepare_data(par)

# %%
means_string = "Data ny def/mean_matrix.csv"
covariance_string = "Data ny def/variance_matrix.csv"

variables = ["extensive_v2"]

mean, variance_diag = load_and_process_data(means_string, covariance_string, par, variables)

variance_cut = np.concatenate([
    variance_diag[:40],
    # variance_diag[55:55+70],
    # variance_diag[55+70:55+70+40]
])

diag_inv = 1 / variance_cut
weight = np.diag(diag_inv)

# %%
theta_names = ("chi_base", "chi_total")

theta_final = np.array([90528, 169704])

for i, name in enumerate(theta_names):
    if name == "retirement_age" or name == "retirement_age" or name == "first_retirement":
        setattr(model.par, name, int(theta_final[i]))
    
    else:
        setattr(model.par, name, theta_final[i])

# %%
def randomize_theta_init(theta_init, bounds, pct=0.05):
    randomized = []
    for val, (lower, upper) in zip(theta_init, bounds):
        delta = pct * val
        min_val = max(lower, val - delta)
        max_val = min(upper, val + delta)
        randomized_val = np.random.uniform(min_val, max_val)
        randomized.append(randomized_val)
    return np.array(randomized)

# Prepare SMM
# theta_names = ("sigma", "gamma", "mu", "zeta", "gamma_1", "gamma_2")

# theta_init = np.array([1.1324159182, 0.6371231124, 6.5, 2.8582779690, 0.1812484876, 4.8808529427])

theta_names = ("rho", "chi_total", "gamma_1", "gamma_2")

theta_init = np.array([0.3, 150000.0, 0.09884474, 3.25370956])

# Original bounds
# orig_bounds = [(0.1, 6.0),   # sigma
#                (0.1, 10.0),  # gamma
#                (0.0, 20.0),  # mu
#                (0.0, 15.0),  # zeta
#                (0.0, 0.3),  # gamma_1
#                (0.01, 10.0)   # gamma_2
#                ] 

               # Original bounds
orig_bounds = [
               (0.0, 1.0),   # rho
               (100000, 220000),  # chi_total
               (0.0, 0.3),  # gamma_1
               (0.01, 10.0)   # gamma_2
               ] 

theta_init_scaled = scale_params(theta_init, orig_bounds)

theta_random = randomize_theta_init(theta_init, orig_bounds)
theta_random_scaled = scale_params(theta_random, orig_bounds)

# Do SMM
objective = lambda theta: obj_func(theta, theta_names, mean, weight, model, orig_bounds, do_print=True)

res = minimize(
    objective, 
    theta_init_scaled,
    method='nelder-mead',
    bounds=[(0,1)] * len(theta_init_scaled),
    tol=1e-6,
    options={"maxiter":2000}
)

theta_final = unscale_params(res.x, orig_bounds)

print(theta_final)
# Out:
# 0.3000000000, 150000.0000000000, 0.0988447400, 3.2537095600,
# Error = 0.93840, Time = 99.9 seconds
# 0.3150000000, 150000.0000000000, 0.0988447400, 3.2537095600,
# Error = 1.05912, Time = 32.0 seconds
# 0.3000000000, 152500.0000000000, 0.0988447400, 3.2537095600,
# Error = 0.87827, Time = 31.9 seconds
# 0.3000000000, 150000.0000000000, 0.1037869770, 3.2537095600,
# Error = 0.81682, Time = 32.0 seconds
# 0.3000000000, 150000.0000000000, 0.0988447400, 3.4158950380,
# Error = 0.94464, Time = 47.9 seconds
# 0.2850000000, 151250.0000000000, 0.1013158585, 3.3348022990,
# Error = 0.80728, Time = 62.3 seconds
# 0.2700000000, 151875.0000000000, 0.1025514178, 3.3753486685,
# Error = 0.71695, Time = 61.6 seconds
# 0.2850000000, 152187.5000000000, 0.1031691974, 3.1523436362,
# Error = 0.72644, Time = 61.4 seconds
# 0.2775000000, 153281.2500000000, 0.1053314261, 3.2638461524,
# Error = 0.64388, Time = 202.0 seconds
# 0.2662500000, 154921.8750000000, 0.1085747691, 3.2689144486,
# Error = 0.55526, Time = 59.6 seconds
# 0.2606250000, 151992.1875000000, 0.1101964406, 3.2714485967,
# Error = 0.56754, Time = 60.7 seconds
# 0.2409375000, 155488.2812500000, 0.1084589354, 3.2803181150,
# Error = 0.47207, Time = 61.7 seconds
# 0.2114062500, 158232.4218750001, 0.1107949146, 3.2936223925,
# Error = 0.43954, Time = 59.8 seconds
# 0.2191406250, 156323.2421875001, 0.1128895737, 3.4523234168,
# Error = 0.43135, Time = 59.4 seconds
# 0.1862109375, 158391.1132812501, 0.1177497618, 3.6023133071,
# Error = 0.51114, Time = 59.0 seconds
# 0.2087109375, 158859.8632812501, 0.1186764312, 3.2678057588,
# Error = 0.51172, Time = 509.6 seconds
# 0.1921289062, 162176.5136718751, 0.1152714037, 3.3698844117,
# Error = 0.52860, Time = 59.2 seconds
# 0.1494433594, 162874.1455078126, 0.1202413925, 3.4229035413,
# Error = 0.70210, Time = 59.1 seconds
# 0.2370483398, 156909.9426269532, 0.1114914250, 3.3074117218,
# Error = 0.44180, Time = 59.2 seconds
# 0.2460241699, 152986.2213134766, 0.1116547685, 3.2906972333,
# Error = 0.52332, Time = 174.8 seconds
# 0.2325503540, 155283.7944030762, 0.1125589273, 3.3104940279,
# Error = 0.44680, Time = 59.9 seconds
# 0.2413618469, 154514.8372650147, 0.1051909890, 3.4141200207,
# Error = 0.51361, Time = 59.4 seconds
# 0.2168736649, 157773.6067771912, 0.1153050707, 3.3043843243,
# Error = 0.45636, Time = 59.3 seconds
# 0.2331991196, 155601.0937690735, 0.1085623496, 3.3775414552,
# Error = 0.46188, Time = 59.8 seconds
# 0.2209550285, 157230.4785251618, 0.1136193904, 3.3226736070,
# Error = 0.43866, Time = 59.7 seconds
# 0.2117247677, 159064.2482042313, 0.1118387245, 3.3775215412,
# Error = 0.44361, Time = 60.2 seconds
# 0.2169311643, 158119.1347539425, 0.1120187752, 3.3607646628,
# Error = 0.43879, Time = 60.1 seconds
# 0.1971681941, 158042.6960438491, 0.1131699020, 3.4072803178,
# Error = 0.45755, Time = 59.5 seconds
# 0.2270783034, 157193.1309811771, 0.1119110442, 3.3323788708,
# Error = 0.42071, Time = 60.4 seconds
# 0.2306463106, 156200.5713488907, 0.1144244771, 3.4404478863,
# Error = 0.42887, Time = 60.1 seconds
# 0.2319789695, 155354.5767674223, 0.1144034675, 3.4131472276,
# Error = 0.44096, Time = 60.3 seconds
# 0.2206931156, 157427.9952573125, 0.1126149483, 3.3738603040,
# Error = 0.43615, Time = 59.8 seconds
# 0.2278241487, 156341.9913622784, 0.1123006312, 3.4768316320,
# Error = 0.42512, Time = 59.9 seconds
# 0.2316515783, 155601.4726826107, 0.1131479148, 3.4771305989,
# Error = 0.44001, Time = 59.2 seconds
# 0.2234327313, 156971.3646136370, 0.1127481899, 3.3996778777,
# Error = 0.42693, Time = 59.6 seconds
# 0.2353501220, 157030.2869654916, 0.1128025976, 3.3723447165,
# Error = 0.43454, Time = 59.3 seconds
# 0.2231929992, 156500.0033819980, 0.1128678296, 3.4323287418,
# Error = 0.42421, Time = 59.3 seconds
# 0.2201177807, 157302.6738206545, 0.1104893704, 3.3801606749,
# Error = 0.43277, Time = 59.6 seconds
# 0.2280141781, 156476.0969668317, 0.1134407004, 3.4253760834,
# Error = 0.42404, Time = 59.4 seconds
# 0.2296220835, 156284.2467325056, 0.1125119128, 3.4337797862,
# Error = 0.42766, Time = 59.9 seconds
# 0.2249800693, 156799.5851433542, 0.1126891206, 3.4082033549,
# Error = 0.42268, Time = 59.5 seconds
# 0.2238086263, 157142.4168744021, 0.1131537162, 3.3223118934,
# Error = 0.43021, Time = 59.7 seconds
# 0.2268202681, 156542.0977403093, 0.1125139025, 3.4382016973,
# Error = 0.42216, Time = 59.3 seconds
# 0.2302534102, 157005.4520338382, 0.1124095542, 3.3697512614,
# Error = 0.42410, Time = 59.6 seconds
# 0.2284883075, 156879.0898708781, 0.1125241231, 3.3853956315,
# Error = 0.42242, Time = 59.4 seconds
# 0.2256692960, 157230.8549010277, 0.1113783948, 3.3567136938,
# Error = 0.42315, Time = 59.8 seconds
# 0.2262555166, 157042.1654174787, 0.1118939712, 3.3738792912,
# Error = 0.42045, Time = 59.4 seconds
# 0.2293411285, 157028.6568615675, 0.1117323998, 3.3567243906,
# Error = 0.42311, Time = 60.0 seconds
# 0.2260703341, 156856.8530729075, 0.1124499404, 3.3953336138,
# Error = 0.42038, Time = 209.9 seconds
# 0.2246239036, 156938.0337350582, 0.1118603061, 3.3845011050,
# Error = 0.42364, Time = 58.9 seconds
# 0.2275222065, 156893.8258369231, 0.1123581688, 3.3851719999,
# Error = 0.42172, Time = 62.2 seconds
# 0.2266429122, 157450.8899139339, 0.1117926599, 3.3051801905,
# Error = 0.42331, Time = 62.4 seconds
# 0.2267759291, 156769.2957837155, 0.1123335918, 3.4049463206,
# Error = 0.42141, Time = 60.1 seconds
# 0.2255678351, 157036.8967907162, 0.1119361050, 3.3680970483,
# Error = 0.42232, Time = 56.2 seconds
# 0.2270336137, 156929.5935753714, 0.1122526529, 3.3809032620,
# Error = 0.42088, Time = 37.1 seconds
# 0.2264429547, 157241.5757397519, 0.1119202125, 3.3363011983,
# Error = 0.42216, Time = 38.2 seconds
# 0.2266926855, 156887.3657727246, 0.1122302470, 3.3877850400,

# %%
model.par.rho = 0.3
model.par.chi_base = 10
model.par.chi_total = 150000
model.par.efterloen = 200000

# %%
model.par.first_retirement + model.par.early_benefits_lag
# Out:
# 31

# %%
# Save model.sim.ex as txt file
np.savetxt("model_sim_ex.txt", model.sim.ex, fmt="%d")
np.savetxt("model_sim_chi_payment.txt", model.sim.chi_payment, fmt="%d")

# %%
np.where(model.sim.ex == 0, model.sim.chi_payment, np.nan)
# Out:
# array([[       nan,        nan,        nan, ..., 98889.4308, 98889.4308,
#         98889.4308],
#        [       nan,        nan,        nan, ..., 98889.4308, 98889.4308,
#         98889.4308],
#        [       nan,        nan,        nan, ..., 98889.4308, 98889.4308,
#         98889.4308],
#        ...,
#        [       nan,        nan,        nan, ..., 98889.4308, 98889.4308,
#         98889.4308],
#        [       nan,        nan,        nan, ..., 98889.4308, 98889.4308,
#         98889.4308],
#        [       nan,        nan,        nan, ..., 98889.4308, 98889.4308,
#         98889.4308]], shape=(50000, 70))

# %%
plt.plot(np.nanmean(np.where(model.sim.ex == 0, model.sim.chi_payment, np.nan), axis=0))

# %%
# theta_names = ("chi_base", "chi_total")
# # # theta_final = unscale_params(res.x, orig_bounds)
# # # theta_final = theta_init

# theta_final = np.array([90528, 169704])

# for i, name in enumerate(theta_names):
#     if name == "retirement_age" or name == "retirement_age" or name == "first_retirement":
#         setattr(model.par, name, int(theta_final[i]))
    
#     else:
#         setattr(model.par, name, theta_final[i])



# Load the model with calibrated values
theta_names = ("gamma_1", "gamma_2")
# # theta_names = ("beta", "zeta")

# theta_final = unscale_params(res.x, orig_bounds)

theta_final = np.array([0.09884474, 3.25370956])

for i, name in enumerate(theta_names):
    setattr(model.par, name, theta_final[i])


model.solve()
model.simulate()

# plot the graph with calibrated values 
a_dict = {
    'hours': [np.nanmean(np.where(model.sim.ex == 1, model.sim.h, np.nan),axis=0)[:45], moments['hours']],
    'extensive': [np.mean(model.sim.ex, axis=0)[:45], moments['extensive']],
    'illiquid': [np.clip(np.mean(model.sim.s, axis=0), 0, None), moments['savings']],
    'liquid': [np.mean(model.sim.a, axis=0), moments['assets']]
}

# Define colors
simulated_color = "navy"  # Dark blue
empirical_color = "darkred"  # Dark red
ci_color = "lightcoral"  # Light red for confidence bands

for key, (simulated, empirical) in a_dict.items():
    plt.figure(figsize=(10, 5))
    
    x_vals = np.arange(len(empirical)) + par.start_age
    
    plt.plot(x_vals, simulated, label=f"Simulated {key.capitalize()}", marker="o", color=simulated_color)
    plt.plot(x_vals, empirical, label=f"Empirical {key.capitalize()}", linestyle="--", marker="s", color=empirical_color)

    # # 99.9% confidence interval
    # ci = std_dev
    # plt.fill_between(x_vals, empirical - ci, empirical + ci, color=ci_color, alpha=0.4, label="Empirical Standard Deviation")

    plt.xlabel("Age")
    plt.ylabel(key.capitalize())
    plt.title(f"Comparison of Simulated and Empirical {key.capitalize()}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
#take first differences of this np.mean(model.sim.ex, axis=0)[:45]

diff_ex_sim = -np.diff(np.mean(model.sim.ex, axis=0)[:45], axis=0)
diff_ex_moments = -np.diff(moments['extensive'][:45], axis=0)
plt.plot(diff_ex_sim, label='Simulated')
plt.plot(diff_ex_moments, label='Empirical')
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Replacement rates

# %%
mask = model.sim.a > 0
c_filtered_mean = np.nanmean(np.where(mask, model.sim.c, np.nan), axis=0)

plt.plot(x_vals, c_filtered_mean, label='Simulated Consumption')
plt.ylim(0, 250000)
# Out:
# (0.0, 250000.0)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mask = model.sim.ex == 1
c_filtered_mean = np.nanmean(np.where(mask, model.sim.w, np.nan), axis=0)

plt.plot(x_vals, c_filtered_mean, label='Simulated Consumption')
# plt.ylim(0, 250000)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np

w = model.sim.w
p5_w = np.percentile(w, 5, axis=0)
p50_w = np.percentile(w, 50, axis=0)
p95_w = np.percentile(w, 95, axis=0)

plt.figure()
plt.plot(p5_w, label='p5')
plt.plot(p50_w, label='p50')
plt.plot(p95_w, label='p95')
plt.xlabel('Time')
plt.ylabel('Assets')
plt.title('Asset distribution over time')
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np

a = model.sim.a
p5 = np.percentile(a, 5, axis=0)
p50 = np.percentile(a, 50, axis=0)
p95 = np.percentile(a, 95, axis=0)

plt.figure()
plt.plot(p5, label='p5')
plt.plot(p50, label='p50')
plt.plot(p95, label='p95')
plt.xlabel('Time')
plt.ylabel('Assets')
plt.title('Asset distribution over time')
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np

c = model.sim.c
p5_c  = np.percentile(c, 5, axis=0)
p50_c = np.percentile(c, 50, axis=0)
p95_c = np.percentile(c, 95, axis=0)

plt.figure()
plt.plot(p5_c, label='p5')
plt.plot(p50_c, label='p50')
plt.plot(p95_c, label='p95')
plt.xlabel('Time')
plt.ylabel('Consumption')
plt.title('Consumption distribution over time')
plt.legend()
plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(x_vals, model.sim.chi_payment.mean(axis=0), label='Simulated Chi Payment')
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pre_retirement_income = np.nanmean(np.where(model.sim.ex == 1, model.sim.income, np.nan))
post_retirement_income = np.nanmean(np.where(model.sim.ex == 0, model.sim.income, np.nan))  

replacement_rate = post_retirement_income / pre_retirement_income
print(f"Replacement Rate: {replacement_rate:.2f}")
# Out:
# Replacement Rate: 0.75
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(
    x_vals,
    np.nanmean(
        np.where(model.sim.ex == 1, model.sim.h, np.nan),
        axis=0
    ),
    label='Simulated Income'
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# prepare your data dict
a_dict = {
    'hours': [np.nanmean(np.where(model.sim.ex == 1, model.sim.h, np.nan), axis=0)[:55],
              moments['hours']],
    'extensive': [np.mean(model.sim.ex, axis=0)[:55],
                  moments['extensive']],
    'liquid': [np.mean(model.sim.a, axis=0),
               moments['assets']]
}
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plot_model_vs_data_grid(a_dict, title="", save_title="in_sample_fit.png")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
means_data = pd.read_csv("Data/mean_matrix.csv")

b_dict = {
    'illiquid': [np.clip(np.clip(np.mean(model.sim.s, axis=0), 0, None) / 1_000_000, 0, None),
                 moments['savings'] / 1_000_000]  ,
    'wages':    [np.nanmean(np.where(model.sim.ex==1, model.sim.w, np.nan)[:, :40] , axis=0),
                 means_data[means_data["alder"] <= 60]["hourly_salary_plsats_Mean"].to_numpy() * 1924]
        }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(np.nanmean(np.where(model.sim.ex==1, model.sim.w, np.nan)[:, :40] , axis=0))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plot_model_vs_data_grid_oos(b_dict, title="", save_title="out_of_sample_fit.png")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(np.nanmean(np.where(model.sim.ex==1, model.sim.w, np.nan)[:, :31] , axis=0))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
